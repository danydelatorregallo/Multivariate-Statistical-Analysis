# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
import statsmodels.stats.api as sms
from scipy import stats
from statsmodels.compat import lzip
from sklearn import linear_model
from sklearn.model_selection import train_test_split

# %%
#%% Cargar base de datos
#Boston House prices
 data_url = "http://lib.stat.cmu.edu/datasets/boston"
 raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
 data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])

# CRIM - per capita crime rate by town
# ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
# INDUS - proportion of non-retail business acres per town.
# CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
# NOX - nitric oxides concentration (parts per 10 million)
# RM - average number of rooms per dwelling
# AGE - proportion of owner-occupied units built prior to 1940
# DIS - weighted distances to five Boston employment centres
# RAD - index of accessibility to radial highways
# TAX - full-value property-tax rate per $10,000
# PTRATIO - pupil-teacher ratio by town
# B - 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
# LSTAT - % lower status of the population
# MEDV - Median value of owner-occupied homes in $1000's
# Out:
#   Cell In[2], line 3
#     data_url = "http://lib.stat.cmu.edu/datasets/boston"
#     ^
# IndentationError: unexpected indent

# %%
#%% Regresión lineal múltiple
# #%% Incluyendo algunas variables
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
X_multiple=np.matrix(data[:,5:8])
Y_multiple=raw_df.values[1::2, 2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 6
#       1 #%% Regresión lineal múltiple
#       2 # #%% Incluyendo algunas variables
#       3 #         - RM       average number of rooms per dwelling
#       4 #         - AGE      proportion of owner-occupied units built prior to 1940
#       5 #         - DIS      weighted distances to five Boston employment centres
# ----> 6 X_multiple=np.matrix(data[:,5:8])
#       7 Y_multiple=raw_df.values[1::2, 2]
#
# NameError: name 'data' is not defined

# %%
#%% # Dividir los datos en conjuntos de entrenamiento y prueba
X_train,X_test,Y_train,Y_test=train_test_split(X_multiple,Y_multiple, test_size=0.2)

# Agregar una constante para el término independiente (B0)
X_train = sm.add_constant(X_train)

# Crear un modelo de regresión lineal múltiple con los datos de entrenamiento
modelo = sm.OLS(Y_train, X_train).fit()

# Obtener los resultados del modelo
print(modelo.summary())

# Ahora puedes usar el modelo para hacer predicciones en los datos de prueba
X_test = sm.add_constant(X_test)
Y_pred = modelo.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 #%% # Dividir los datos en conjuntos de entrenamiento y prueba
# ----> 2 X_train,X_test,Y_train,Y_test=train_test_split(X_multiple,Y_multiple, test_size=0.2)
#       4 # Agregar una constante para el término independiente (B0)
#       5 X_train = sm.add_constant(X_train)
#
# NameError: name 'X_multiple' is not defined

# %%
#%% Visualizar homocedasticidad 
error=Y_test-Y_pred
plt.scatter(Y_pred, error, marker='*', alpha=0.6)
plt.axhline(y=0, color='r', linestyle='--')
plt.xlabel('Valores Ajustados')
plt.ylabel('Residuos')
plt.title('Homocedasticidad')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 2
#       1 #%% Visualizar homocedasticidad
# ----> 2 error=Y_test-Y_pred
#       3 plt.scatter(Y_pred, error, marker='*', alpha=0.6)
#       4 plt.axhline(y=0, color='r', linestyle='--')
#
# NameError: name 'Y_test' is not defined

# %%
#%% Forma Estadística de Homocedasticidad
#Breusch-Pagan
#H0: Homocedasticidad (p>0.05)
#H1: No homocedasticidad (p<0.05)
names=['Lagrange multiplier statistic', 'p-value',
        'f-value', 'f p-value']
test = sms.het_breuschpagan(modelo.resid, X_train)
lzip(names, test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 7
#       1 #%% Forma Estadística de Homocedasticidad
#       2 #Breusch-Pagan
#       3 #H0: Homocedasticidad (p>0.05)
#       4 #H1: No homocedasticidad (p<0.05)
#       5 names=['Lagrange multiplier statistic', 'p-value',
#       6         'f-value', 'f p-value']
# ----> 7 test = sms.het_breuschpagan(modelo.resid, X_train)
#       8 lzip(names, test)
#
# NameError: name 'modelo' is not defined

# %%
#%% Forma gráfica de la  normalidad de los residuos
plt.figure()
plt.hist(modelo.resid)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 #%% Forma gráfica de la  normalidad de los residuos
#       2 plt.figure()
# ----> 3 plt.hist(modelo.resid)
#       4 plt.show()
#
# NameError: name 'modelo' is not defined

# %%
#%% QQ plot

qq_plot = sm.qqplot(modelo.resid, line='45', fit=True)

# Personalizar la apariencia del QQ plot
plt.title("QQ Plot de los Residuos")
plt.xlabel("Cuantiles Teóricos")
plt.ylabel("Cuantiles de los Residuos")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 #%% QQ plot
# ----> 3 qq_plot = sm.qqplot(modelo.resid, line='45', fit=True)
#       5 # Personalizar la apariencia del QQ plot
#       6 plt.title("QQ Plot de los Residuos")
#
# NameError: name 'modelo' is not defined

# %%
#%% Forma estadística de la normalidda (Shapiro-Wilk)
#Ho: Normalidad (p>0.05)
#H1: No normalidad (p<0.05)
names=[' Statistic', 'p-value']
test=stats.shapiro(modelo.resid)
lzip(names,test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 5
#       1 #%% Forma estadística de la normalidda (Shapiro-Wilk)
#       2 #Ho: Normalidad (p>0.05)
#       3 #H1: No normalidad (p<0.05)
#       4 names=[' Statistic', 'p-value']
# ----> 5 test=stats.shapiro(modelo.resid)
#       6 lzip(names,test)
#
# NameError: name 'modelo' is not defined
